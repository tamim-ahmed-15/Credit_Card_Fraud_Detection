# %% [markdown]
# # Importing Pandas and Loading dataset

# %%
import pandas as pd

#dataset loading
data = pd.read_csv('creditcard.csv')
data.head(10) #shows only first 10 rows
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %% [markdown]
# # Inspecting Data

# %%
print("Dataset Shape:", data.shape)
print("\nColumn Names:\n", data.columns)
print("\nData Types:\n", data.dtypes)
# Out:
# Dataset Shape: (284807, 31)
#
# Column Names:
#  Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#
# Data Types:
#  Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
print("\nSummary Statistics:\n", data.describe())
# Out:
# Summary Statistics:
#                  Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
#finding null values
print("\nMissing Values:\n", data.isnull().sum())
# Out:
# Missing Values:
#  Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print("\nClass Distribution:\n", data['Class'].value_counts())
# Out:
# Class Distribution:
#  Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# # 1. Histograms for Amount and Time

# %%
plt.figure(figsize=(12, 5))

# Histogram for Amount
plt.subplot(1, 2, 1)
sns.histplot(data['Amount'], bins=50, kde=True, color='blue')
plt.title('Distribution of Transaction Amount')
plt.xlabel('Amount ($)')
plt.ylabel('Count')

# Histogram for Time
plt.subplot(1, 2, 2)
sns.histplot(data['Time'], bins=50, kde=True, color='green')
plt.title('Distribution of Transaction Time')
plt.xlabel('Time (seconds)')
plt.ylabel('Count')

plt.tight_layout()
plt.savefig('histograms.png')  
plt.show()

# %% [markdown]
# # 2. Correlation Matrix

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm', center=0, annot=False)
plt.title('Correlation Matrix of Features')
plt.savefig('correlation_matrix.png')  
plt.show()

# %% [markdown]
# # Counting Normal and Fraude Transaction

# %%
# Counting transactions by class
transaction_counts = data['Class'].value_counts()

# Calculating percentages
total_transactions = len(data)
transaction_percentages = (transaction_counts / total_transactions) * 100

# Normal transactions
print(f"Number of normal transactions: {transaction_counts[0]} ({transaction_percentages[0]:.2f}%)")

# Fraud Transactions
print(f"Number of fraud transactions: {transaction_counts[1]} ({transaction_percentages[1]:.2f}%)")
# Out:
# Number of normal transactions: 284315 (99.83%)
# Number of fraud transactions: 492 (0.17%)

# %% [markdown]
# # 3. Fraud vs. Normal Distribution

# %%
# Count Plot with Log Scale and Annotations
plt.figure(figsize=(6, 4))
ax = sns.countplot(data=data, x='Class', palette='Set1')
plt.title("Fraud (1) vs Normal (0) Transaction Count (Log Scale)")
plt.xlabel("Class")
plt.ylabel("Log Count")
plt.xticks([0, 1], ['Normal', 'Fraud'])
plt.yscale('log')  

# Counting Annotate
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig('count_plot_log.png') 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2400\4052845169.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=data, x='Class', palette='Set1')

# %% [markdown]
# # 4. Create the boxplot for Amount by Class

# %%
# plt.figure(figsize=(10,6))
# sns.boxplot(x='Class', y='Amount', data=data)
# plt.ylim(0, 300)
# plt.title('Transaction Amount by Class')
# plt.xlabel('Class (0: Normal, 1: Fraud)')
# plt.ylabel('Transaction Amount')
# plt.show()

palette = ['#1f77b4', '#ff7f0e']  # blue, orange

plt.figure(figsize=(10,6))
sns.boxplot(x='Class', y='Amount', data=data, palette=palette)
plt.ylim(0, 300)
plt.title('Transaction Amount by Class')
plt.xlabel('Class (0: Normal, 1: Fraud)')
plt.ylabel('Transaction Amount')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2400\1908258705.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Class', y='Amount', data=data, palette=palette)
